# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
# !wget -q https://learnopencv.com/wp-content/uploads/2024/08/soccer-scaled.jpg -O football.jpg
# !wget -q https://learnopencv.com/wp-content/uploads/2024/08/zebra-yolov10-scaled.jpg -O zebra.jpg
# !wget -q https://learnopencv.com/wp-content/uploads/2024/08/monitor-yolov10-scaled.jpg -O monitor.jpg
# !wget -q https://learnopencv.com/wp-content/uploads/2024/08/kitchen-scaled.jpg -O kitchen.jpg
# !wget -q https://learnopencv.com/wp-content/uploads/2024/08/cat-dog-yolov10-v1.jpeg -O cat-dog.jpg
# !wget -q https://learnopencv.com/wp-content/uploads/2025/02/tiger-scaled.jpg -O tiger.jpg
# !wget -q https://learnopencv.com/wp-content/uploads/2025/02/boat-ob.jpg -O boat.jpg

# %% [markdown]
# <h3>Common Utility</h3>

# %%
def prediction(model_type, img_path, display_result = False, task: str = None):
    model = YOLO(model_type)
    result = model(img_path, save = True, conf=0.5)
    
    for r in result:
        pred_img_path = f"{r.save_dir}/{img_path}"
        pred = cv2.cvtColor(cv2.imread(pred_img_path), cv2.COLOR_BGR2RGB)
        plt.imshow(pred)
        plt.axis('off')
        plt.title(f"YOLO11 - {task}")
    plt.show()
    
    if display_result:
        print(result)

# %% [markdown]
# <h3>Object Detection</h3>

# %%
# Load the pre-trained YOLOv11-Medium model
img_path = "football.jpg"
model_type = "yolo11l.pt"

prediction(model_type, img_path, task = "Object Detection")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11l.pt to 'yolo11l.pt'...
# 100%|██████████| 49.0M/49.0M [00:12<00:00, 4.09MB/s]
# image 1/1 /Users/research/Documents/learning/pytorch-explore/football.jpg: 448x640 4 persons, 1 sports ball, 198.2ms
# Speed: 2.9ms preprocess, 198.2ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /Users/research/Documents/learning/pytorch-explore/runs/detect/predict

# %%
img_path = "zebra.jpg"
prediction(model_type, img_path, display_result= True, task = "Object Detection")
# Out:
# image 1/1 /Users/research/Documents/learning/pytorch-explore/zebra.jpg: 448x640 5 zebras, 168.0ms
# Speed: 1.8ms preprocess, 168.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /Users/research/Documents/learning/pytorch-explore/runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[179, 126,  93],
#         [180, 127,  94],
#         [182, 129,  96],
#         ...,
#         [210, 180, 163],
#         [210, 180, 163],
#         [213, 181, 168]],
#
#        [[180, 127,  94],
#         [181, 128,  95],
#         [181, 128,  95],
#         ...,
#         [210, 180, 163],
#         [210, 180, 163],
#         [211, 180, 165]],
#
#        [[181, 128,  95],
#         [181, 128,  95],
#         [181, 128,  95],
#         ...,
#         [210, 180, 163],
#         [210, 180, 163],
#         [209, 178, 163]],
#
#        ...,
#
#        [[ 53, 104, 130],
#         [ 52, 103, 129],
#         [ 50, 101, 127],
#         ...,
#         [ 68,  98, 133],
#         [ 66,  98, 133],
#         [ 63,  99, 129]],
#
#        [[ 54, 105, 131],
#         [ 53, 104, 130],
#         [ 51, 102, 128],
#         ...,
#         [ 67,  94, 131],
#         [ 66,  96, 131],
#         [ 62,  98, 128]],
#
#        [[ 53, 104, 130],
#         [ 53, 104, 130],
#         [ 53, 104, 130],
#         ...,
#         [ 65,  92, 129],
#         [ 64,  94, 129],
#         [ 61,  97, 127]]], dtype=uint8)
# orig_shape: (1024, 1537)
# path: '/Users/research/Documents/learning/pytorch-explore/zebra.jpg'
# probs: None
# save_dir: '/Users/research/Documents/learning/pytorch-explore/runs/detect/predict2'
# speed: {'preprocess': 1.797707998775877, 'inference': 167.95041600016702, 'postprocess': 0.7344999994529644}]

# %%
img_path = "monitor.jpg"
prediction(model_type, img_path, task = "Object Detection")
# Out:
# image 1/1 /Users/research/Documents/learning/pytorch-explore/monitor.jpg: 448x640 1 person, 1 tv, 1 mouse, 1 keyboard, 1 cell phone, 164.9ms
# Speed: 1.8ms preprocess, 164.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /Users/research/Documents/learning/pytorch-explore/runs/detect/predict3

# %%
img_path = "kitchen.jpg"
prediction(model_type, img_path, task = "Object Detection")
# Out:
# image 1/1 /Users/research/Documents/learning/pytorch-explore/kitchen.jpg: 448x640 2 cups, 1 bowl, 1 dining table, 2 ovens, 1 sink, 1 refrigerator, 164.6ms
# Speed: 4.7ms preprocess, 164.6ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /Users/research/Documents/learning/pytorch-explore/runs/detect/predict4

# %%
img_path = "cat-dog.jpg"
prediction(model_type, img_path, task = "Object Detection")
# Out:
# image 1/1 /Users/research/Documents/learning/pytorch-explore/cat-dog.jpg: 640x448 1 cat, 1 dog, 2 potted plants, 166.9ms
# Speed: 1.2ms preprocess, 166.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to /Users/research/Documents/learning/pytorch-explore/runs/detect/predict5

# %% [markdown]
# <h3>Pose Estimation</h3>

# %%
model_type = "yolo11l-pose.pt"

# %%
img_path = "football.jpg"

# Predict with the model
prediction(model_type, img_path, task = "Pose Estimation")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11l-pose.pt to 'yolo11l-pose.pt'...
# 100%|██████████| 50.7M/50.7M [00:28<00:00, 1.88MB/s]
# image 1/1 /Users/research/Documents/learning/pytorch-explore/football.jpg: 448x640 4 persons, 194.8ms
# Speed: 1.4ms preprocess, 194.8ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /Users/research/Documents/learning/pytorch-explore/runs/pose/predict

# %% [markdown]
# <h3>Instance Segmentation</h3>

# %%
# Load a model
model_type = "yolo11l-seg.pt"

# %%
img_path = "football.jpg"

# Predict with the model
prediction(model_type, img_path, task = "Instance Segmentation")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11l-seg.pt to 'yolo11l-seg.pt'...
# 100%|██████████| 53.5M/53.5M [00:13<00:00, 4.21MB/s]
# image 1/1 /Users/research/Documents/learning/pytorch-explore/football.jpg: 448x640 4 persons, 1 sports ball, 306.9ms
# Speed: 2.9ms preprocess, 306.9ms inference, 4.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /Users/research/Documents/learning/pytorch-explore/runs/segment/predict

# %% [markdown]
# <h3>Classification</h3>

# %%
model_type = "yolo11l-cls.pt"

# %%
img_path = "tiger.jpg"

# Predict with the model
prediction(model_type, img_path, task = "Classification")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11l-cls.pt to 'yolo11l-cls.pt'...
# 100%|██████████| 27.2M/27.2M [00:06<00:00, 4.13MB/s]
# image 1/1 /Users/research/Documents/learning/pytorch-explore/tiger.jpg: 224x224 tiger 0.70, tiger_cat 0.29, jaguar 0.00, lynx 0.00, cheetah 0.00, 28.7ms
# Speed: 25.8ms preprocess, 28.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /Users/research/Documents/learning/pytorch-explore/runs/classify/predict

# %% [markdown]
# <h3>Oritented Bounding Box</h3>

# %%
model_type = "yolo11l-obb.pt"

# %%
img_path = "boat.jpg"

prediction(model_type, img_path, task = "OBB")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11l-obb.pt to 'yolo11l-obb.pt'...
# 100%|██████████| 50.7M/50.7M [00:14<00:00, 3.59MB/s]
# image 1/1 /Users/research/Documents/learning/pytorch-explore/boat.jpg: 1024x768 577.9ms
# Speed: 3.6ms preprocess, 577.9ms inference, 2.4ms postprocess per image at shape (1, 3, 1024, 768)
# Results saved to /Users/research/Documents/learning/pytorch-explore/runs/obb/predict
